# %% [markdown]
# Using Test Train Split

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df=pd.read_csv("Dataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X_train, X_test, Y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

model = RandomForestClassifier(max_depth=2, random_state=0)

skf = StratifiedKFold(n_splits=10)
scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

for k, (train_index, test_index) in enumerate(skf.split(X_train, Y_train)):
    X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    Y_train_fold, Y_test_fold = Y_train.iloc[train_index], Y_train.iloc[test_index]
    
    model.fit(X_train_fold, Y_train_fold)
    y_pred = model.predict(X_test_fold)
    
    score = accuracy_score(Y_test_fold, y_pred)
    precision = precision_score(Y_test_fold, y_pred)
    recall = recall_score(Y_test_fold, y_pred)
    balanced_accuracy = balanced_accuracy_score(Y_test_fold, y_pred)
    f1 = f1_score(Y_test_fold, y_pred)
    confusion = confusion_matrix(Y_test_fold, y_pred)
    
    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)
    
    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d' % (k+1))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
        score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1
# Accuracy: 0.583, Precision: 0.600, Specificity: 0.667, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.583, F1 Score: 0.545
# Confusion Matrix:
#  [[12  6]
#  [ 9  9]]
#
#
# Fold:  2
# Accuracy: 0.694, Precision: 0.684, Specificity: 0.667, Sensitivity: 0.722, Recall: 0.722
# Balanced Accuracy: 0.694, F1 Score: 0.703
# Confusion Matrix:
#  [[12  6]
#  [ 5 13]]
#
#
# Fold:  3
# Accuracy: 0.778, Precision: 0.727, Specificity: 0.667, Sensitivity: 0.889, Recall: 0.889
# Balanced Accuracy: 0.778, F1 Score: 0.800
# Confusion Matrix:
#  [[12  6]
#  [ 2 16]]
#
#
# Fold:  4
# Accuracy: 0.722, Precision: 0.700, Specificity: 0.667, Sensitivity: 0.778, Recall: 0.778
# Balanced Accuracy: 0.722, F1 Score: 0.737
# Confusion Matrix:
#  [[12  6]
#  [ 4 14]]
#
#
# Fold:  5
# Accuracy: 0.639, Precision: 0.632, Specificity: 0.611, Sensitivity: 0.667, Recall: 0.667
# Balanced Accuracy: 0.639, F1 Score: 0.649
# Confusion Matrix:
#  [[11  7]
#  [ 6 12]]
#
#
# Fold:  6
# Accuracy: 0.694, Precision: 0.684, Specificity: 0.667, Sensitivity: 0.722, Recall: 0.722
# Balanced Accuracy: 0.694, F1 Score: 0.703
# Confusion Matrix:
#  [[12  6]
#  [ 5 13]]
#
#
# Fold:  7
# Accuracy: 0.778, Precision: 0.857, Specificity: 0.889, Sensitivity: 0.667, Recall: 0.667
# Balanced Accuracy: 0.778, F1 Score: 0.750
# Confusion Matrix:
#  [[16  2]
#  [ 6 12]]
#
#
# Fold:  8
# Accuracy: 0.743, Precision: 0.737, Specificity: 0.706, Sensitivity: 0.778, Recall: 0.778
# Balanced Accuracy: 0.742, F1 Score: 0.757
# Confusion Matrix:
#  [[12  5]
#  [ 4 14]]
#
#
# Fold:  9
# Accuracy: 0.714, Precision: 0.682, Specificity: 0.588, Sensitivity: 0.833, Recall: 0.833
# Balanced Accuracy: 0.711, F1 Score: 0.750
# Confusion Matrix:
#  [[10  7]
#  [ 3 15]]
#
#
# Fold: 10
# Accuracy: 0.771, Precision: 0.750, Specificity: 0.706, Sensitivity: 0.833, Recall: 0.833
# Balanced Accuracy: 0.770, F1 Score: 0.789
# Confusion Matrix:
#  [[12  5]
#  [ 3 15]]
#
#
# Mean Accuracy: 0.712, Precision: 0.705, Specificity: 0.683, Sensitivity: 0.739, Recall: 0.739
# Mean Balanced Accuracy: 0.711, F1 Score: 0.718
# Mean Confusion Matrix:
#  [[12.1  5.6]
#  [ 4.7 13.3]]
#
#
# Cross-Validation Accuracy: 0.712 +/- 0.060

# %% [markdown]
# Using Test & Train Dataset

# %%
d=pd.read_csv("TestDataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
x_test=d.iloc[:,:-1]
y_test=d.iloc[:,-1]

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

strtfdKFold = StratifiedKFold(n_splits=10)
kfold = strtfdKFold.split(X, Y)

scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

model = RandomForestClassifier(max_depth=2, random_state=0)

for k, (train, test) in enumerate(kfold):
    model.fit(X.iloc[train], Y.iloc[train])
    y_pred = model.predict(X.iloc[test])
    score = accuracy_score(Y.iloc[test], y_pred)
    precision = precision_score(Y.iloc[test], y_pred)
    recall = recall_score(Y.iloc[test], y_pred)
    balanced_accuracy = balanced_accuracy_score(Y.iloc[test], y_pred)
    f1 = f1_score(Y.iloc[test], y_pred)
    confusion = confusion_matrix(Y.iloc[test], y_pred)

    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)

    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d, Training/Test Split Distribution: %s' % (k + 1, np.bincount(Y.iloc[train])))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Training/Test Split Distribution: [204 198]
# Accuracy: 0.556, Precision: 0.545, Specificity: 0.565, Sensitivity: 0.545, Recall: 0.545
# Balanced Accuracy: 0.555, F1 Score: 0.545
# Confusion Matrix:
#  [[13 10]
#  [10 12]]
#
#
# Fold:  2, Training/Test Split Distribution: [204 198]
# Accuracy: 0.911, Precision: 0.909, Specificity: 0.913, Sensitivity: 0.909, Recall: 0.909
# Balanced Accuracy: 0.911, F1 Score: 0.909
# Confusion Matrix:
#  [[21  2]
#  [ 2 20]]
#
#
# Fold:  3, Training/Test Split Distribution: [204 198]
# Accuracy: 0.933, Precision: 1.000, Specificity: 1.000, Sensitivity: 0.864, Recall: 0.864
# Balanced Accuracy: 0.932, F1 Score: 0.927
# Confusion Matrix:
#  [[23  0]
#  [ 3 19]]
#
#
# Fold:  4, Training/Test Split Distribution: [204 198]
# Accuracy: 0.644, Precision: 0.594, Specificity: 0.435, Sensitivity: 0.864, Recall: 0.864
# Balanced Accuracy: 0.649, F1 Score: 0.704
# Confusion Matrix:
#  [[10 13]
#  [ 3 19]]
#
#
# Fold:  5, Training/Test Split Distribution: [204 198]
# Accuracy: 0.511, Precision: 0.500, Specificity: 0.522, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.511, F1 Score: 0.500
# Confusion Matrix:
#  [[12 11]
#  [11 11]]
#
#
# Fold:  6, Training/Test Split Distribution: [204 198]
# Accuracy: 0.467, Precision: 0.475, Specificity: 0.087, Sensitivity: 0.864, Recall: 0.864
# Balanced Accuracy: 0.475, F1 Score: 0.613
# Confusion Matrix:
#  [[ 2 21]
#  [ 3 19]]
#
#
# Fold:  7, Training/Test Split Distribution: [204 198]
# Accuracy: 0.489, Precision: 0.471, Specificity: 0.609, Sensitivity: 0.364, Recall: 0.364
# Balanced Accuracy: 0.486, F1 Score: 0.410
# Confusion Matrix:
#  [[14  9]
#  [14  8]]
#
#
# Fold:  8, Training/Test Split Distribution: [205 198]
# Accuracy: 0.523, Precision: 0.519, Specificity: 0.409, Sensitivity: 0.636, Recall: 0.636
# Balanced Accuracy: 0.523, F1 Score: 0.571
# Confusion Matrix:
#  [[ 9 13]
#  [ 8 14]]
#
#
# Fold:  9, Training/Test Split Distribution: [205 198]
# Accuracy: 0.773, Precision: 1.000, Specificity: 1.000, Sensitivity: 0.545, Recall: 0.545
# Balanced Accuracy: 0.773, F1 Score: 0.706
# Confusion Matrix:
#  [[22  0]
#  [10 12]]
#
#
# Fold: 10, Training/Test Split Distribution: [205 198]
# Accuracy: 0.773, Precision: 0.929, Specificity: 0.955, Sensitivity: 0.591, Recall: 0.591
# Balanced Accuracy: 0.773, F1 Score: 0.722
# Confusion Matrix:
#  [[21  1]
#  [ 9 13]]
#
#
#
#
# Cross-Validation Accuracy: 0.658 +/- 0.168
# Mean Accuracy: 0.658, Precision: 0.694, Specificity: 0.649, Sensitivity: 0.668, Recall: 0.668
# Mean Balanced Accuracy: 0.659, F1 Score: 0.661
# Mean Confusion Matrix:
#  [[14.7  8. ]
#  [ 7.3 14.7]]
#
#
# Cross-Validation Accuracy: 0.658 +/- 0.168
