# %% [markdown]
# Using test train split

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df=pd.read_csv("Dataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X_train, X_test, Y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

model = SVC(kernel='linear')

skf = StratifiedKFold(n_splits=10)
scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

for k, (train_index, test_index) in enumerate(skf.split(X_train, Y_train)):
    X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    Y_train_fold, Y_test_fold = Y_train.iloc[train_index], Y_train.iloc[test_index]
    
    model.fit(X_train_fold, Y_train_fold)
    y_pred = model.predict(X_test_fold)
    
    score = accuracy_score(Y_test_fold, y_pred)
    precision = precision_score(Y_test_fold, y_pred)
    recall = recall_score(Y_test_fold, y_pred)
    balanced_accuracy = balanced_accuracy_score(Y_test_fold, y_pred)
    f1 = f1_score(Y_test_fold, y_pred)
    confusion = confusion_matrix(Y_test_fold, y_pred)
    
    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)
    
    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d' % (k+1))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
        score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1
# Accuracy: 0.694, Precision: 0.714, Specificity: 0.789, Sensitivity: 0.588, Recall: 0.588
# Balanced Accuracy: 0.689, F1 Score: 0.645
# Confusion Matrix:
#  [[15  4]
#  [ 7 10]]
#
#
# Fold:  2
# Accuracy: 0.583, Precision: 0.560, Specificity: 0.389, Sensitivity: 0.778, Recall: 0.778
# Balanced Accuracy: 0.583, F1 Score: 0.651
# Confusion Matrix:
#  [[ 7 11]
#  [ 4 14]]
#
#
# Fold:  3
# Accuracy: 0.556, Precision: 0.571, Specificity: 0.667, Sensitivity: 0.444, Recall: 0.444
# Balanced Accuracy: 0.556, F1 Score: 0.500
# Confusion Matrix:
#  [[12  6]
#  [10  8]]
#
#
# Fold:  4
# Accuracy: 0.667, Precision: 0.650, Specificity: 0.611, Sensitivity: 0.722, Recall: 0.722
# Balanced Accuracy: 0.667, F1 Score: 0.684
# Confusion Matrix:
#  [[11  7]
#  [ 5 13]]
#
#
# Fold:  5
# Accuracy: 0.694, Precision: 0.733, Specificity: 0.778, Sensitivity: 0.611, Recall: 0.611
# Balanced Accuracy: 0.694, F1 Score: 0.667
# Confusion Matrix:
#  [[14  4]
#  [ 7 11]]
#
#
# Fold:  6
# Accuracy: 0.722, Precision: 0.722, Specificity: 0.722, Sensitivity: 0.722, Recall: 0.722
# Balanced Accuracy: 0.722, F1 Score: 0.722
# Confusion Matrix:
#  [[13  5]
#  [ 5 13]]
#
#
# Fold:  7
# Accuracy: 0.694, Precision: 0.667, Specificity: 0.611, Sensitivity: 0.778, Recall: 0.778
# Balanced Accuracy: 0.694, F1 Score: 0.718
# Confusion Matrix:
#  [[11  7]
#  [ 4 14]]
#
#
# Fold:  8
# Accuracy: 0.686, Precision: 0.688, Specificity: 0.722, Sensitivity: 0.647, Recall: 0.647
# Balanced Accuracy: 0.685, F1 Score: 0.667
# Confusion Matrix:
#  [[13  5]
#  [ 6 11]]
#
#
# Fold:  9
# Accuracy: 0.686, Precision: 0.750, Specificity: 0.833, Sensitivity: 0.529, Recall: 0.529
# Balanced Accuracy: 0.681, F1 Score: 0.621
# Confusion Matrix:
#  [[15  3]
#  [ 8  9]]
#
#
# Fold: 10
# Accuracy: 0.714, Precision: 0.706, Specificity: 0.722, Sensitivity: 0.706, Recall: 0.706
# Balanced Accuracy: 0.714, F1 Score: 0.706
# Confusion Matrix:
#  [[13  5]
#  [ 5 12]]
#
#
# Mean Accuracy: 0.670, Precision: 0.676, Specificity: 0.685, Sensitivity: 0.653, Recall: 0.653
# Mean Balanced Accuracy: 0.669, F1 Score: 0.658
# Mean Confusion Matrix:
#  [[12.4  5.7]
#  [ 6.1 11.5]]
#
#
# Cross-Validation Accuracy: 0.670 +/- 0.053

# %% [markdown]
# Using seperate test & train dataset

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

strtfdKFold = StratifiedKFold(n_splits=10)
kfold = strtfdKFold.split(X, Y)

scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

model = SVC(kernel='linear')

for k, (train, test) in enumerate(kfold):
    model.fit(X.iloc[train], Y.iloc[train])
    y_pred = model.predict(X.iloc[test])
    score = accuracy_score(Y.iloc[test], y_pred)
    precision = precision_score(Y.iloc[test], y_pred)
    recall = recall_score(Y.iloc[test], y_pred)
    balanced_accuracy = balanced_accuracy_score(Y.iloc[test], y_pred)
    f1 = f1_score(Y.iloc[test], y_pred)
    confusion = confusion_matrix(Y.iloc[test], y_pred)

    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)

    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d, Training/Test Split Distribution: %s' % (k + 1, np.bincount(Y.iloc[train])))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Training/Test Split Distribution: [204 198]
# Accuracy: 0.667, Precision: 0.652, Specificity: 0.652, Sensitivity: 0.682, Recall: 0.682
# Balanced Accuracy: 0.667, F1 Score: 0.667
# Confusion Matrix:
#  [[15  8]
#  [ 7 15]]
#
#
# Fold:  2, Training/Test Split Distribution: [204 198]
# Accuracy: 0.644, Precision: 0.625, Specificity: 0.609, Sensitivity: 0.682, Recall: 0.682
# Balanced Accuracy: 0.645, F1 Score: 0.652
# Confusion Matrix:
#  [[14  9]
#  [ 7 15]]
#
#
# Fold:  3, Training/Test Split Distribution: [204 198]
# Accuracy: 0.756, Precision: 0.762, Specificity: 0.783, Sensitivity: 0.727, Recall: 0.727
# Balanced Accuracy: 0.755, F1 Score: 0.744
# Confusion Matrix:
#  [[18  5]
#  [ 6 16]]
#
#
# Fold:  4, Training/Test Split Distribution: [204 198]
# Accuracy: 0.644, Precision: 0.667, Specificity: 0.739, Sensitivity: 0.545, Recall: 0.545
# Balanced Accuracy: 0.642, F1 Score: 0.600
# Confusion Matrix:
#  [[17  6]
#  [10 12]]
#
#
# Fold:  5, Training/Test Split Distribution: [204 198]
# Accuracy: 0.400, Precision: 0.414, Specificity: 0.261, Sensitivity: 0.545, Recall: 0.545
# Balanced Accuracy: 0.403, F1 Score: 0.471
# Confusion Matrix:
#  [[ 6 17]
#  [10 12]]
#
#
# Fold:  6, Training/Test Split Distribution: [204 198]
# Accuracy: 0.489, Precision: 0.474, Specificity: 0.565, Sensitivity: 0.409, Recall: 0.409
# Balanced Accuracy: 0.487, F1 Score: 0.439
# Confusion Matrix:
#  [[13 10]
#  [13  9]]
#
#
# Fold:  7, Training/Test Split Distribution: [204 198]
# Accuracy: 0.578, Precision: 0.600, Specificity: 0.739, Sensitivity: 0.409, Recall: 0.409
# Balanced Accuracy: 0.574, F1 Score: 0.486
# Confusion Matrix:
#  [[17  6]
#  [13  9]]
#
#
# Fold:  8, Training/Test Split Distribution: [205 198]
# Accuracy: 0.523, Precision: 0.526, Specificity: 0.591, Sensitivity: 0.455, Recall: 0.455
# Balanced Accuracy: 0.523, F1 Score: 0.488
# Confusion Matrix:
#  [[13  9]
#  [12 10]]
#
#
# Fold:  9, Training/Test Split Distribution: [205 198]
# Accuracy: 0.545, Precision: 0.542, Specificity: 0.500, Sensitivity: 0.591, Recall: 0.591
# Balanced Accuracy: 0.545, F1 Score: 0.565
# Confusion Matrix:
#  [[11 11]
#  [ 9 13]]
#
#
# Fold: 10, Training/Test Split Distribution: [205 198]
# Accuracy: 0.727, Precision: 0.778, Specificity: 0.818, Sensitivity: 0.636, Recall: 0.636
# Balanced Accuracy: 0.727, F1 Score: 0.700
# Confusion Matrix:
#  [[18  4]
#  [ 8 14]]
#
#
#
#
# Cross-Validation Accuracy: 0.597 +/- 0.105
# Mean Accuracy: 0.597, Precision: 0.604, Specificity: 0.626, Sensitivity: 0.568, Recall: 0.568
# Mean Balanced Accuracy: 0.597, F1 Score: 0.581
# Mean Confusion Matrix:
#  [[14.2  8.5]
#  [ 9.5 12.5]]
#
#
# Cross-Validation Accuracy: 0.597 +/- 0.105
