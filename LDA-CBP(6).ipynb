# %% [markdown]
# Using Test Train Split

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df=pd.read_csv("Dataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X_train, X_test, Y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

model = LinearDiscriminantAnalysis()

skf = StratifiedKFold(n_splits=10)
scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

for k, (train_index, test_index) in enumerate(skf.split(X_train, Y_train)):
    X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    Y_train_fold, Y_test_fold = Y_train.iloc[train_index], Y_train.iloc[test_index]
    
    model.fit(X_train_fold, Y_train_fold)
    y_pred = model.predict(X_test_fold)
    
    score = accuracy_score(Y_test_fold, y_pred)
    precision = precision_score(Y_test_fold, y_pred)
    recall = recall_score(Y_test_fold, y_pred)
    balanced_accuracy = balanced_accuracy_score(Y_test_fold, y_pred)
    f1 = f1_score(Y_test_fold, y_pred)
    confusion = confusion_matrix(Y_test_fold, y_pred)
    
    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)
    
    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d' % (k+1))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
        score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1
# Accuracy: 0.611, Precision: 0.611, Specificity: 0.611, Sensitivity: 0.611, Recall: 0.611
# Balanced Accuracy: 0.611, F1 Score: 0.611
# Confusion Matrix:
#  [[11  7]
#  [ 7 11]]
#
#
# Fold:  2
# Accuracy: 0.750, Precision: 0.765, Specificity: 0.778, Sensitivity: 0.722, Recall: 0.722
# Balanced Accuracy: 0.750, F1 Score: 0.743
# Confusion Matrix:
#  [[14  4]
#  [ 5 13]]
#
#
# Fold:  3
# Accuracy: 0.667, Precision: 0.650, Specificity: 0.611, Sensitivity: 0.722, Recall: 0.722
# Balanced Accuracy: 0.667, F1 Score: 0.684
# Confusion Matrix:
#  [[11  7]
#  [ 5 13]]
#
#
# Fold:  4
# Accuracy: 0.667, Precision: 0.667, Specificity: 0.667, Sensitivity: 0.667, Recall: 0.667
# Balanced Accuracy: 0.667, F1 Score: 0.667
# Confusion Matrix:
#  [[12  6]
#  [ 6 12]]
#
#
# Fold:  5
# Accuracy: 0.639, Precision: 0.727, Specificity: 0.833, Sensitivity: 0.444, Recall: 0.444
# Balanced Accuracy: 0.639, F1 Score: 0.552
# Confusion Matrix:
#  [[15  3]
#  [10  8]]
#
#
# Fold:  6
# Accuracy: 0.611, Precision: 0.600, Specificity: 0.556, Sensitivity: 0.667, Recall: 0.667
# Balanced Accuracy: 0.611, F1 Score: 0.632
# Confusion Matrix:
#  [[10  8]
#  [ 6 12]]
#
#
# Fold:  7
# Accuracy: 0.750, Precision: 0.714, Specificity: 0.667, Sensitivity: 0.833, Recall: 0.833
# Balanced Accuracy: 0.750, F1 Score: 0.769
# Confusion Matrix:
#  [[12  6]
#  [ 3 15]]
#
#
# Fold:  8
# Accuracy: 0.657, Precision: 0.632, Specificity: 0.611, Sensitivity: 0.706, Recall: 0.706
# Balanced Accuracy: 0.658, F1 Score: 0.667
# Confusion Matrix:
#  [[11  7]
#  [ 5 12]]
#
#
# Fold:  9
# Accuracy: 0.543, Precision: 0.533, Specificity: 0.611, Sensitivity: 0.471, Recall: 0.471
# Balanced Accuracy: 0.541, F1 Score: 0.500
# Confusion Matrix:
#  [[11  7]
#  [ 9  8]]
#
#
# Fold: 10
# Accuracy: 0.657, Precision: 0.750, Specificity: 0.824, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.662, F1 Score: 0.600
# Confusion Matrix:
#  [[14  3]
#  [ 9  9]]
#
#
# Mean Accuracy: 0.655, Precision: 0.665, Specificity: 0.677, Sensitivity: 0.634, Recall: 0.634
# Mean Balanced Accuracy: 0.656, F1 Score: 0.642
# Mean Confusion Matrix:
#  [[12.1  5.8]
#  [ 6.5 11.3]]
#
#
# Cross-Validation Accuracy: 0.655 +/- 0.059

# %% [markdown]
# Using seperate test & train dataset

# %%
d=pd.read_csv("TestDataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
x_test=d.iloc[:,:-1]
y_test=d.iloc[:,-1]

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

strtfdKFold = StratifiedKFold(n_splits=10)
kfold = strtfdKFold.split(X, Y)

scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

model = LinearDiscriminantAnalysis()

for k, (train, test) in enumerate(kfold):
    model.fit(X.iloc[train], Y.iloc[train])
    y_pred = model.predict(X.iloc[test])
    score = accuracy_score(Y.iloc[test], y_pred)
    precision = precision_score(Y.iloc[test], y_pred)
    recall = recall_score(Y.iloc[test], y_pred)
    balanced_accuracy = balanced_accuracy_score(Y.iloc[test], y_pred)
    f1 = f1_score(Y.iloc[test], y_pred)
    confusion = confusion_matrix(Y.iloc[test], y_pred)

    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)

    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d, Training/Test Split Distribution: %s' % (k + 1, np.bincount(Y.iloc[train])))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Training/Test Split Distribution: [204 198]
# Accuracy: 0.711, Precision: 0.680, Specificity: 0.652, Sensitivity: 0.773, Recall: 0.773
# Balanced Accuracy: 0.712, F1 Score: 0.723
# Confusion Matrix:
#  [[15  8]
#  [ 5 17]]
#
#
# Fold:  2, Training/Test Split Distribution: [204 198]
# Accuracy: 0.578, Precision: 0.565, Specificity: 0.565, Sensitivity: 0.591, Recall: 0.591
# Balanced Accuracy: 0.578, F1 Score: 0.578
# Confusion Matrix:
#  [[13 10]
#  [ 9 13]]
#
#
# Fold:  3, Training/Test Split Distribution: [204 198]
# Accuracy: 0.711, Precision: 0.696, Specificity: 0.696, Sensitivity: 0.727, Recall: 0.727
# Balanced Accuracy: 0.711, F1 Score: 0.711
# Confusion Matrix:
#  [[16  7]
#  [ 6 16]]
#
#
# Fold:  4, Training/Test Split Distribution: [204 198]
# Accuracy: 0.489, Precision: 0.476, Specificity: 0.522, Sensitivity: 0.455, Recall: 0.455
# Balanced Accuracy: 0.488, F1 Score: 0.465
# Confusion Matrix:
#  [[12 11]
#  [12 10]]
#
#
# Fold:  5, Training/Test Split Distribution: [204 198]
# Accuracy: 0.511, Precision: 0.500, Specificity: 0.522, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.511, F1 Score: 0.500
# Confusion Matrix:
#  [[12 11]
#  [11 11]]
#
#
# Fold:  6, Training/Test Split Distribution: [204 198]
# Accuracy: 0.400, Precision: 0.368, Specificity: 0.478, Sensitivity: 0.318, Recall: 0.318
# Balanced Accuracy: 0.398, F1 Score: 0.341
# Confusion Matrix:
#  [[11 12]
#  [15  7]]
#
#
# Fold:  7, Training/Test Split Distribution: [204 198]
# Accuracy: 0.467, Precision: 0.444, Specificity: 0.565, Sensitivity: 0.364, Recall: 0.364
# Balanced Accuracy: 0.464, F1 Score: 0.400
# Confusion Matrix:
#  [[13 10]
#  [14  8]]
#
#
# Fold:  8, Training/Test Split Distribution: [205 198]
# Accuracy: 0.523, Precision: 0.522, Specificity: 0.500, Sensitivity: 0.545, Recall: 0.545
# Balanced Accuracy: 0.523, F1 Score: 0.533
# Confusion Matrix:
#  [[11 11]
#  [10 12]]
#
#
# Fold:  9, Training/Test Split Distribution: [205 198]
# Accuracy: 0.568, Precision: 0.579, Specificity: 0.636, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.568, F1 Score: 0.537
# Confusion Matrix:
#  [[14  8]
#  [11 11]]
#
#
# Fold: 10, Training/Test Split Distribution: [205 198]
# Accuracy: 0.750, Precision: 0.739, Specificity: 0.727, Sensitivity: 0.773, Recall: 0.773
# Balanced Accuracy: 0.750, F1 Score: 0.756
# Confusion Matrix:
#  [[16  6]
#  [ 5 17]]
#
#
#
#
# Cross-Validation Accuracy: 0.571 +/- 0.111
# Mean Accuracy: 0.571, Precision: 0.557, Specificity: 0.586, Sensitivity: 0.555, Recall: 0.555
# Mean Balanced Accuracy: 0.570, F1 Score: 0.554
# Mean Confusion Matrix:
#  [[13.3  9.4]
#  [ 9.8 12.2]]
#
#
# Cross-Validation Accuracy: 0.571 +/- 0.111
