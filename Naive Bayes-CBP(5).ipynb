# %% [markdown]
# Using Train Test Split

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df=pd.read_csv("Dataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X_train, X_test, Y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

model = GaussianNB()

skf = StratifiedKFold(n_splits=10)
scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

for k, (train_index, test_index) in enumerate(skf.split(X_train, Y_train)):
    X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    Y_train_fold, Y_test_fold = Y_train.iloc[train_index], Y_train.iloc[test_index]
    
    model.fit(X_train_fold, Y_train_fold)
    y_pred = model.predict(X_test_fold)
    
    score = accuracy_score(Y_test_fold, y_pred)
    precision = precision_score(Y_test_fold, y_pred)
    recall = recall_score(Y_test_fold, y_pred)
    balanced_accuracy = balanced_accuracy_score(Y_test_fold, y_pred)
    f1 = f1_score(Y_test_fold, y_pred)
    confusion = confusion_matrix(Y_test_fold, y_pred)
    
    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)
    
    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d' % (k+1))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
        score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1
# Accuracy: 0.611, Precision: 0.600, Specificity: 0.684, Sensitivity: 0.529, Recall: 0.529
# Balanced Accuracy: 0.607, F1 Score: 0.562
# Confusion Matrix:
#  [[13  6]
#  [ 8  9]]
#
#
# Fold:  2
# Accuracy: 0.667, Precision: 0.619, Specificity: 0.579, Sensitivity: 0.765, Recall: 0.765
# Balanced Accuracy: 0.672, F1 Score: 0.684
# Confusion Matrix:
#  [[11  8]
#  [ 4 13]]
#
#
# Fold:  3
# Accuracy: 0.583, Precision: 0.636, Specificity: 0.778, Sensitivity: 0.389, Recall: 0.389
# Balanced Accuracy: 0.583, F1 Score: 0.483
# Confusion Matrix:
#  [[14  4]
#  [11  7]]
#
#
# Fold:  4
# Accuracy: 0.722, Precision: 0.750, Specificity: 0.778, Sensitivity: 0.667, Recall: 0.667
# Balanced Accuracy: 0.722, F1 Score: 0.706
# Confusion Matrix:
#  [[14  4]
#  [ 6 12]]
#
#
# Fold:  5
# Accuracy: 0.639, Precision: 0.632, Specificity: 0.611, Sensitivity: 0.667, Recall: 0.667
# Balanced Accuracy: 0.639, F1 Score: 0.649
# Confusion Matrix:
#  [[11  7]
#  [ 6 12]]
#
#
# Fold:  6
# Accuracy: 0.778, Precision: 0.727, Specificity: 0.667, Sensitivity: 0.889, Recall: 0.889
# Balanced Accuracy: 0.778, F1 Score: 0.800
# Confusion Matrix:
#  [[12  6]
#  [ 2 16]]
#
#
# Fold:  7
# Accuracy: 0.611, Precision: 0.625, Specificity: 0.667, Sensitivity: 0.556, Recall: 0.556
# Balanced Accuracy: 0.611, F1 Score: 0.588
# Confusion Matrix:
#  [[12  6]
#  [ 8 10]]
#
#
# Fold:  8
# Accuracy: 0.686, Precision: 0.688, Specificity: 0.722, Sensitivity: 0.647, Recall: 0.647
# Balanced Accuracy: 0.685, F1 Score: 0.667
# Confusion Matrix:
#  [[13  5]
#  [ 6 11]]
#
#
# Fold:  9
# Accuracy: 0.514, Precision: 0.500, Specificity: 0.389, Sensitivity: 0.647, Recall: 0.647
# Balanced Accuracy: 0.518, F1 Score: 0.564
# Confusion Matrix:
#  [[ 7 11]
#  [ 6 11]]
#
#
# Fold: 10
# Accuracy: 0.657, Precision: 0.632, Specificity: 0.611, Sensitivity: 0.706, Recall: 0.706
# Balanced Accuracy: 0.658, F1 Score: 0.667
# Confusion Matrix:
#  [[11  7]
#  [ 5 12]]
#
#
# Mean Accuracy: 0.647, Precision: 0.641, Specificity: 0.649, Sensitivity: 0.646, Recall: 0.646
# Mean Balanced Accuracy: 0.647, F1 Score: 0.637
# Mean Confusion Matrix:
#  [[11.8  6.4]
#  [ 6.2 11.3]]
#
#
# Cross-Validation Accuracy: 0.647 +/- 0.070

# %% [markdown]
# Using Seperate train & test Dataset

# %%
d=pd.read_csv("TestDataset.csv")
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
x_test=d.iloc[:,:-1]
y_test=d.iloc[:,-1]

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

strtfdKFold = StratifiedKFold(n_splits=10)
kfold = strtfdKFold.split(X, Y)

scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

model = GaussianNB()

for k, (train, test) in enumerate(kfold):
    model.fit(X.iloc[train], Y.iloc[train])
    y_pred = model.predict(X.iloc[test])
    score = accuracy_score(Y.iloc[test], y_pred)
    precision = precision_score(Y.iloc[test], y_pred)
    recall = recall_score(Y.iloc[test], y_pred)
    balanced_accuracy = balanced_accuracy_score(Y.iloc[test], y_pred)
    f1 = f1_score(Y.iloc[test], y_pred)
    confusion = confusion_matrix(Y.iloc[test], y_pred)

    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)

    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d, Training/Test Split Distribution: %s' % (k + 1, np.bincount(Y.iloc[train])))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Training/Test Split Distribution: [204 198]
# Accuracy: 0.667, Precision: 0.706, Specificity: 0.783, Sensitivity: 0.545, Recall: 0.545
# Balanced Accuracy: 0.664, F1 Score: 0.615
# Confusion Matrix:
#  [[18  5]
#  [10 12]]
#
#
# Fold:  2, Training/Test Split Distribution: [204 198]
# Accuracy: 0.800, Precision: 0.741, Specificity: 0.696, Sensitivity: 0.909, Recall: 0.909
# Balanced Accuracy: 0.802, F1 Score: 0.816
# Confusion Matrix:
#  [[16  7]
#  [ 2 20]]
#
#
# Fold:  3, Training/Test Split Distribution: [204 198]
# Accuracy: 0.800, Precision: 0.760, Specificity: 0.739, Sensitivity: 0.864, Recall: 0.864
# Balanced Accuracy: 0.801, F1 Score: 0.809
# Confusion Matrix:
#  [[17  6]
#  [ 3 19]]
#
#
# Fold:  4, Training/Test Split Distribution: [204 198]
# Accuracy: 0.778, Precision: 0.731, Specificity: 0.696, Sensitivity: 0.864, Recall: 0.864
# Balanced Accuracy: 0.780, F1 Score: 0.792
# Confusion Matrix:
#  [[16  7]
#  [ 3 19]]
#
#
# Fold:  5, Training/Test Split Distribution: [204 198]
# Accuracy: 0.267, Precision: 0.261, Specificity: 0.261, Sensitivity: 0.273, Recall: 0.273
# Balanced Accuracy: 0.267, F1 Score: 0.267
# Confusion Matrix:
#  [[ 6 17]
#  [16  6]]
#
#
# Fold:  6, Training/Test Split Distribution: [204 198]
# Accuracy: 0.400, Precision: 0.432, Specificity: 0.087, Sensitivity: 0.727, Recall: 0.727
# Balanced Accuracy: 0.407, F1 Score: 0.542
# Confusion Matrix:
#  [[ 2 21]
#  [ 6 16]]
#
#
# Fold:  7, Training/Test Split Distribution: [204 198]
# Accuracy: 0.622, Precision: 0.647, Specificity: 0.739, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.620, F1 Score: 0.564
# Confusion Matrix:
#  [[17  6]
#  [11 11]]
#
#
# Fold:  8, Training/Test Split Distribution: [205 198]
# Accuracy: 0.545, Precision: 0.583, Specificity: 0.773, Sensitivity: 0.318, Recall: 0.318
# Balanced Accuracy: 0.545, F1 Score: 0.412
# Confusion Matrix:
#  [[17  5]
#  [15  7]]
#
#
# Fold:  9, Training/Test Split Distribution: [205 198]
# Accuracy: 0.682, Precision: 0.786, Specificity: 0.864, Sensitivity: 0.500, Recall: 0.500
# Balanced Accuracy: 0.682, F1 Score: 0.611
# Confusion Matrix:
#  [[19  3]
#  [11 11]]
#
#
# Fold: 10, Training/Test Split Distribution: [205 198]
# Accuracy: 0.659, Precision: 0.652, Specificity: 0.636, Sensitivity: 0.682, Recall: 0.682
# Balanced Accuracy: 0.659, F1 Score: 0.667
# Confusion Matrix:
#  [[14  8]
#  [ 7 15]]
#
#
#
#
# Cross-Validation Accuracy: 0.622 +/- 0.166
# Mean Accuracy: 0.622, Precision: 0.630, Specificity: 0.627, Sensitivity: 0.618, Recall: 0.618
# Mean Balanced Accuracy: 0.623, F1 Score: 0.609
# Mean Confusion Matrix:
#  [[14.2  8.5]
#  [ 8.4 13.6]]
#
#
# Cross-Validation Accuracy: 0.622 +/- 0.166
